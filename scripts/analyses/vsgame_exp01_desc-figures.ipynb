# %% [markdown]
# # vsgame_exp01 Figures
# ## Agency broadly enhances memory beyond directly controlled information
# ### Tej Bhoga, Zachariah M. Reagh, and Angelique I. Delarazan

# %% [markdown]
# ## Set Up

# %% [markdown]
# ### Import Packages

# %%
import matplotlib.pyplot as plt
import glob
import os
import pandas as pd
import re
import seaborn as sns
import itertools
import ptitprince as pt

# %% [markdown]
# ### Load Data

# %%
base_dir = '/Users/aidelarazan/Box Sync/aidelarazan_box/Projects/vsgame/exp01/data/'
mst = pd.read_csv(os.path.join(base_dir, 'vsgame_exp01_sub-all_task-MST.csv'))
spatial_placement = pd.read_csv(os.path.join(base_dir, 'vsgame_exp01_sub-all_task-SpatialPlacement.csv'))
item_desc = pd.read_csv(os.path.join(base_dir, 'vsgame_exp01_sub-all_task-ItemRecallDescriptions_desc-SemanticSimilarity.csv'))
excluded_subjects = [152, 161]

# %% [markdown]
# ## MST

# %% [markdown]
# ### dprime

# %%
mst.head()
# Out:
#    subject condition experiment task  target_hit  target_miss  lure_cr  \
# 0      121    Active      exp01  mst          18            3       13
# 1      120    Active      exp01  mst          19            1       12
# 2      122    Active      exp01  mst          13            9        2
# 3      123    Active      exp01  mst          12            4       14
# 4      124    Active      exp01  mst           6            3       14
#
#    lure_fa  foil_cr  foil_fa  ...   fa_rate    dprime  dprime_lures   LDI  \
# 0        8       24        0  ...  0.163265  2.619676      1.050540  0.40
# 1        9       22        2  ...  0.224490  2.089297      1.064761  0.44
# 2       14       23        1  ...  0.306122  1.781818     -0.100816 -0.28
# 3        9       19        5  ...  0.285714  0.762064      0.308305  0.40
# 4        9       21        3  ...  0.244898  0.444047     -0.347844  0.44
#
#    LDI_reviewer      beta         c        ad  foiled_target  foiled_lure
# 0           NaN  1.365406  0.199142  0.968015              3            4
# 1           NaN  1.037882  0.025407  0.930210              1            4
# 2           NaN  1.135646  0.228359  0.896154              9            9
# 3           NaN  1.172211  0.308051  0.705009              4            2
# 4           NaN  0.989115  0.698468  0.623235              3            2
#
# [5 rows x 28 columns]

# %%
mst = mst[~mst['subject'].isin(excluded_subjects)].reset_index(drop=True)

# %%
fig, ax = plt.subplots(figsize=(5, 6), facecolor='none')

xtick_order = ['Active', 'Passive']
xtick_labels = {
    'Active': 'Active',
    'Passive': 'Passive',
}
xtick_colors = {
    'Active': '#006429',
    'Passive': '#80B294',    
}

# Swarmplot
pt.half_violinplot(
    data=mst,
    x='condition',
    y='dprime',
    hue='condition',
    hue_order=xtick_order,
    palette=xtick_colors, 
    bw=0.5, 
    cut=1, 
    scale="area", 
    width=0.5, 
    inner=None,
    order=xtick_order, 
    split=True,
    linewidth=0,
)

# Pointplot
sns.boxplot(
    data=mst,
    x='condition',
    y='dprime',
    palette=xtick_colors, 
    width=0.1, 
    order=xtick_order,
    fliersize=4,
    zorder=10,
    showcaps=False, 
    linewidth=2,
    boxprops={'facecolor': 'none', "zorder": 10, 'linewidth': 2},
    showfliers=True, 
    whiskerprops={'linewidth': 2, "zorder": 10}
)

# Pointplot
sns.stripplot(
    data=mst,
    x='condition',
    y='dprime',
    palette=xtick_colors, 
    edgecolor="black",
    size=7, 
    jitter=1, 
    zorder=0,
    order=xtick_order
)

# Axis labels and ticks
ax.set_ylabel("Basic Object Recognition\n(d')", fontsize=20)
ax.set_xlabel('')
ax.set_xticks(range(len(xtick_order)))
ax.set_xticklabels([xtick_labels[label] for label in xtick_order])

# Add significance line
xy = (0, 4)
xytext = (1, 4)
center = ((xy[0] + xytext[0]) / 2, (xy[1] + xytext[1]) / 2)

ax.annotate('', xy=xy, xytext=xytext, arrowprops=dict(arrowstyle='-', color='black'))
ax.text(center[0], center[1] + .1, '***', ha='center', va='bottom', fontsize=16)

# Adjust plot limits and aesthetics
ax.set_ylim(-2, 4.6)
ax.tick_params(labelsize=16)
ax.legend_.remove()

plt.savefig('/Users/aidelarazan/Box Sync/aidelarazan_box/Projects/vsgame/figures/vsgame_exp01_sub-all_task-MST_desc-dprime.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### LDI

# %%
fig, ax = plt.subplots(figsize=(5, 6), facecolor='none')

xtick_order = ['Active', 'Passive']
xtick_labels = {
    'Active': 'Active',
    'Passive': 'Passive',
}
xtick_colors = {
    'Active': '#2a3f67',
    'Passive': '#6b7a8d',
}

# Swarmplot
pt.half_violinplot(
    data=mst,
    x='condition',
    y='LDI',
    hue='condition',
    hue_order=xtick_order,
    palette=xtick_colors, 
    bw=0.5, 
    cut=1, 
    scale="area", 
    width=0.5, 
    inner=None,
    order=xtick_order, 
    split=True,
    linewidth=0,
)

# Pointplot
sns.boxplot(
    data=mst,
    x='condition',
    y='LDI',
    palette=xtick_colors, 
    width=0.1, 
    order=xtick_order,
    fliersize=4,
    zorder=10,
    showcaps=False, 
    linewidth=2,
    boxprops={'facecolor': 'none', "zorder": 10, 'linewidth': 2},
    showfliers=True, 
    whiskerprops={'linewidth': 2, "zorder": 10}
)

# Pointplot
sns.stripplot(
    data=mst,
    x='condition',
    y='LDI',
    palette=xtick_colors, 
    edgecolor="black",
    size=7, 
    jitter=1, 
    zorder=0,
    order=xtick_order
)

# Axis labels and ticks
ax.set_ylabel("Lure Discrimination Index\n(LDI)", fontsize=20)
ax.set_xlabel('')
ax.set_xticks(range(len(xtick_order)))
ax.set_xticklabels([xtick_labels[label] for label in xtick_order])

# # Add significance line
xy = (0, 1.1)
xytext = (1, 1.1)
center = ((xy[0] + xytext[0]) / 2, (xy[1] + xytext[1]) / 2)

ax.annotate('', xy=xy, xytext=xytext, arrowprops=dict(arrowstyle='-', color='black'))
ax.text(center[0], center[1] + .1, '**', ha='center', va='bottom', fontsize=16)

# # Adjust plot limits and aesthetics
ax.set_ylim(-1.25, 1.4)
ax.tick_params(labelsize=16)
ax.legend_.remove()

plt.savefig('/Users/aidelarazan/Box Sync/aidelarazan_box/Projects/vsgame/figures/vsgame_exp01_sub-all_task-MST_desc-ldi.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Spatial Placement

# %%
spatial_placement.head()
# Out:
#    subject condition experiment               task item_category        item  \
# 0      121    Active      exp01  spatial_placement        target  alarmclock
# 1      121    Active      exp01  spatial_placement        target   applecore
# 2      121    Active      exp01  spatial_placement          lure    bikepump
# 3      121    Active      exp01  spatial_placement        target  binoculars
# 4      121    Active      exp01  spatial_placement          lure     blender
#
#    response_x  response_y  correct_response_x  correct_response_y    distance
# 0         345         364                 119                 361  226.019911
# 1         354         355                 392                 350   38.327536
# 2         186         310                 439                 350  256.142538
# 3         134         338                 270                 339  136.003676
# 4         258         135                 333                 170   82.764727

# %%
spatial_placement = spatial_placement[~spatial_placement['subject'].isin(excluded_subjects)].reset_index(drop=True)

# %%
spatial_placement  = spatial_placement.groupby(['subject', 'condition', 'experiment']).mean('distance').reset_index()

# %%
fig, ax = plt.subplots(figsize=(5, 6), facecolor='none')

xtick_order = ['Active', 'Passive'] 
xtick_labels = {
    'Active': 'Active',
    'Passive': 'Passive',
}
xtick_colors = {
    'Active': '#91323d',
    'Passive': '#b27077',  
}

# Swarmplot
pt.half_violinplot(
    data=spatial_placement,
    x='condition',
    y='distance',
    hue='condition',
    hue_order=xtick_order,
    palette=xtick_colors, 
    bw=0.5, 
    cut=1, 
    scale="area", 
    width=0.5, 
    inner=None,
    order=xtick_order, 
    split=True,
    linewidth=0,
)

# Pointplot
sns.boxplot(
    data=spatial_placement,
    x='condition',
    y='distance',
    palette=xtick_colors, 
    width=0.1, 
    order=xtick_order,
    fliersize=4,
    zorder=10,
    showcaps=False, 
    linewidth=2,
    boxprops={'facecolor': 'none', "zorder": 10, 'linewidth': 2},
    showfliers=True, 
    whiskerprops={'linewidth': 2, "zorder": 10}
)

# Pointplot
sns.stripplot(
    data=spatial_placement,
    x='condition',
    y='distance',
    palette=xtick_colors, 
    edgecolor="black",
    size=7, 
    jitter=1, 
    zorder=0,
    order=xtick_order
)

# Axis labels and ticks
ax.set_ylabel('Object-Spatial Placement\n(Error)', fontsize=20)
ax.set_xlabel('')
ax.set_xticks(range(len(xtick_order)))
ax.set_xticklabels([xtick_labels[label] for label in xtick_order])

# # # Add significance line
# xy = (0, 1.1)
# xytext = (1, 1.1)
# center = ((xy[0] + xytext[0]) / 2, (xy[1] + xytext[1]) / 2)

# ax.annotate('', xy=xy, xytext=xytext, arrowprops=dict(arrowstyle='-', color='black'))
# ax.text(center[0], center[1] + .01, '***', ha='center', va='bottom', fontsize=16)

# # Adjust plot limits and aesthetics
# ax.set_ylim(-0.1, 1.19)
ax.tick_params(labelsize=16)
ax.legend_.remove()

plt.savefig('/Users/aidelarazan/Box Sync/aidelarazan_box/Projects/vsgame/figures/vsgame_exp01_sub-all_task-SpatialPlacement_desc-Error.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Item Description Recall

# %%
item_desc = item_desc.groupby(['subject', 'condition', 'experiment']).mean('semantic_similarity').reset_index()
item_desc = item_desc[~item_desc['subject'].isin(excluded_subjects)].reset_index(drop=True)
item_desc
# Out:
#     subject condition experiment  semantic_similarity
# 0       120    Active      exp01             0.357643
# 1       121    Active      exp01             0.550803
# 2       122    Active      exp01             0.148501
# 3       123    Active      exp01             0.367485
# 4       124    Active      exp01             0.385723
# ..      ...       ...        ...                  ...
# 83      263   Passive      exp01             0.181157
# 84      264   Passive      exp01             0.272611
# 85      265   Passive      exp01             0.412058
# 86      266   Passive      exp01             0.419876
# 87      267   Passive      exp01            -0.013803
#
# [88 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 6), facecolor='none')

xtick_order = ['Active', 'Passive'] 
xtick_labels = {
    'Active': 'Active',
    'Passive': 'Passive',
}

xtick_colors = {
    'Active': '#571a65',
    'Passive': '#8f6798',  
}

# Swarmplot
pt.half_violinplot(
    data=item_desc,
    x='condition',
    y='semantic_similarity',
    hue='condition',
    hue_order=xtick_order,
    palette=xtick_colors, 
    bw=0.5, 
    cut=1, 
    scale="area", 
    width=0.5, 
    inner=None,
    order=xtick_order, 
    split=True,
    linewidth=0,
)

# Pointplot
sns.boxplot(
    data=item_desc,
    x='condition',
    y='semantic_similarity',
    palette=xtick_colors, 
    width=0.1, 
    order=xtick_order,
    fliersize=4,
    zorder=10,
    showcaps=False, 
    linewidth=2,
    boxprops={'facecolor': 'none', "zorder": 10, 'linewidth': 2},
    showfliers=True, 
    whiskerprops={'linewidth': 2, "zorder": 10}
)

# Pointplot
sns.stripplot(
    data=item_desc,
    x='condition',
    y='semantic_similarity',
    palette=xtick_colors, 
    edgecolor="black",
    size=7, 
    jitter=1, 
    zorder=0,
    order=xtick_order
)

# Axis labels and ticks
ax.set_ylabel('Object Description Recall\n(Semantic Similarity)', fontsize=20)
ax.set_xlabel('')
ax.set_xticks(range(len(xtick_order)))
ax.set_xticklabels([xtick_labels[label] for label in xtick_order])

# # Add significance line
xy = (0, .7)
xytext = (1, .7)
center = ((xy[0] + xytext[0]) / 2, (xy[1] + xytext[1]) / 2)

ax.annotate('', xy=xy, xytext=xytext, arrowprops=dict(arrowstyle='-', color='black'))
ax.text(center[0], center[1] + .01, '*', ha='center', va='bottom', fontsize=16)

# Adjust plot limits and aesthetics
ax.set_ylim(-0.09, .8)
ax.tick_params(labelsize=16)
ax.legend_.remove()

plt.savefig('/Users/aidelarazan/Box Sync/aidelarazan_box/Projects/vsgame/figures/vsgame_exp01_sub-all_task-ItemDescriptionRecall_desc-SemanticSimilarity.png', dpi=300, bbox_inches='tight')
plt.show()
